# %%
import tensorflow as tf

model = tf.keras.models.load_model("../saved_models/1finalm.keras")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model
with open("model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Admin\AppData\Local\Temp\tmpx7h4ijr_\assets
# INFO:tensorflow:Assets written to: C:\Users\Admin\AppData\Local\Temp\tmpx7h4ijr_\assets
# Saved artifact at 'C:\Users\Admin\AppData\Local\Temp\tmpx7h4ijr_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2206452826768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452830416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452830800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452831760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452832336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452833296: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Optimize Recommended for Mobile
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Enable optimization
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model = converter.convert()

with open("model_optimized.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Admin\AppData\Local\Temp\tmp_hf7_su9\assets
# INFO:tensorflow:Assets written to: C:\Users\Admin\AppData\Local\Temp\tmp_hf7_su9\assets
# Saved artifact at 'C:\Users\Admin\AppData\Local\Temp\tmp_hf7_su9'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2206452826768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452830416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452830800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452831760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452832336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452833296: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Dynamic Range Quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model = converter.convert()

with open("model_quant.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Admin\AppData\Local\Temp\tmpe5bmx4g3\assets
# INFO:tensorflow:Assets written to: C:\Users\Admin\AppData\Local\Temp\tmpe5bmx4g3\assets
# Saved artifact at 'C:\Users\Admin\AppData\Local\Temp\tmpe5bmx4g3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2206452826768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452827344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452829840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452828688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452830416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452830800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452831760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452832336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2206452833296: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# check the input and output details of the model
interpreter = tf.lite.Interpreter(model_path="model.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test with one image
input_shape = input_details[0]['shape']

print(input_shape)
# Out:
# [  1 256 256   3]
